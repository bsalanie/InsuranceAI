# %%
import constant_rho_two
import datetime

# %%
NAME_OF_EXPERIMENT = "9_5_bootstrap_hard_skip"
constant_rho_two.run(experiment_name=NAME_OF_EXPERIMENT,
                     rho_test=None, 
                     power_test_or_bootstrap_choice=1, 
                     mu_4_choice=1, # Simple is 0, hard is 1
                     skip_estimating_fhat=True,
                     enable_one_hot=True) # simple is 0, hard is 1
# Out:
# All best ro found (first is original data): [-0.00382682 -0.00845696 -0.03016388  0.03374581 -0.02108035 -0.00667288
#   0.03355828 -0.03265249  0.03482123  0.0404961   0.01231948 -0.04286619
#  -0.01452322 -0.0191385   0.01334515 -0.00321863  0.00046374 -0.00452944
#  -0.04474332  0.01421514  0.01038051  0.0076515   0.04958056 -0.05279876
#  -0.01050213  0.02230829  0.02017082  0.01148274 -0.01815431 -0.04643128
#   0.03956397 -0.0176349  -0.01345391 -0.02384     0.02935085  0.01181706
#  -0.01559754 -0.04807385 -0.02278996  0.01548236  0.02432433  0.04046167
#   0.03148766 -0.01277491 -0.00622364 -0.00890015 -0.01172501  0.00748149
#   0.00063637 -0.01360872 -0.03214616  0.00886139 -0.01944894 -0.05752572
#   0.02336098  0.01508674  0.04045525  0.0169906  -0.00967056  0.02384775
#  -0.00186233  0.01464342  0.02127645  0.00560231 -0.03211152  0.01874984
#   0.00258861 -0.00538297  0.04477026  0.01275231 -0.00987819  0.01588529
# ...

# %%
#%%javascript
#IPython.notebook.save_notebook()

# %%
#from paths import *
#OUTPUT_FOLDER = GENERAL_RESULTS_FOLDER+NAME_OF_EXPERIMENT+"/" # don't forget the /
# convert this notebook to html and save it in the folder
#RUN_BOOTSTRAP_NO_EXTENSION = "run_bootstrap"
#FULL_NOTEBOOK_HTML_PATH = OUTPUT_FOLDER+RUN_BOOTSTRAP_NO_EXTENSION+".html"
#FULL_NOTEBOOK_PDF_PATH = PDF_FOLDER+NAME_OF_EXPERIMENT+DASHES+RUN_BOOTSTRAP_NO_EXTENSION+".pdf"
#! jupyter nbconvert --to html Run_Bootstrap.ipynb  
#! wkhtmltopdf Run_Bootstrap.html Run_Bootstrap.pdf 
#! mv Run_Bootstrap.html $FULL_NOTEBOOK_HTML_PATH
#! mv Run_Bootstrap.pdf $FULL_NOTEBOOK_PDF_PATH
# Out:
# [NbConvertApp] Converting notebook Run_Bootstrap.ipynb to html
# [NbConvertApp] Writing 579270 bytes to Run_Bootstrap.html
# Loading page (1/2)
# Printing pages (2/2)
# Done
